# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv("placement-dataset.csv")
dataset.head(3)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="iq",data=dataset,hue="placement")
plt.legend(loc=1)
plt.show()

# %%
x = dataset[["cgpa", "iq"]]
y=dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel="linear")
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.score(x_test,y_test)
# Out:
# 0.95

# %%
svc.score(x_train,y_train)
# Out:
# 0.9125

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=svc)
plt.show()
# Out:
# C:\Users\shubh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
